# %% [markdown]
# ## Problem (unicode1): Understanding Unicode (1 point)

# %% [markdown]
# (a) What Unicode character does `chr(0)` return?

# %%
chr(0)
# Out:
# '\x00'

# %% [markdown]
# (b) How does this character’s string representation (`__repr__()`) differ from its printed representation?

# %%
print(chr(0))
repr(chr(0))
# Out:
# "'\\x00'"

# %% [markdown]
# (c) What happens when this character occurs in text? It may be helpful to play around with the
# following in your Python interpreter and see if it matches your expectations:
#
# ```python
# chr(0)
# print(chr(0))
# "this is a test" + chr(0) + "string"
# print("this is a test" + chr(0) + "string")
# ```

# %%
print(chr(0))
print("this is a test" + chr(0) + "string")
# Out:
# this is a teststring

# %% [markdown]
# ## Problem (unicode2): Unicode Encodings

# %% [markdown]
# (a) What are some reasons to prefer training our tokenizer on UTF-8 encoded bytes, rather than
# UTF-16 or UTF-32? It may be helpful to compare the output of these encodings for various
# input strings.

# %%
test_string = "hello! こんにちは!"
utf8_encoded = test_string.encode("utf-8")
utf16_encoded = test_string.encode("utf-16")
utf32_encoded = test_string.encode("utf-32")
print(utf8_encoded)
print(utf16_encoded)
print(utf32_encoded)
# Out:
# b'hello! \xe3\x81\x93\xe3\x82\x93\xe3\x81\xab\xe3\x81\xa1\xe3\x81\xaf!'
# b'\xff\xfeh\x00e\x00l\x00l\x00o\x00!\x00 \x00S0\x930k0a0o0!\x00'
# b'\xff\xfe\x00\x00h\x00\x00\x00e\x00\x00\x00l\x00\x00\x00l\x00\x00\x00o\x00\x00\x00!\x00\x00\x00 \x00\x00\x00S0\x00\x00\x930\x00\x00k0\x00\x00a0\x00\x00o0\x00\x00!\x00\x00\x00'

# %%
test_string = "I love you!"
utf8_encoded = test_string.encode("utf-8")
utf16_encoded = test_string.encode("utf-16")
utf32_encoded = test_string.encode("utf-32")
print(utf8_encoded)
print(utf16_encoded)
print(utf32_encoded)
# Out:
# b'I love you!'
# b'\xff\xfeI\x00 \x00l\x00o\x00v\x00e\x00 \x00y\x00o\x00u\x00!\x00'
# b'\xff\xfe\x00\x00I\x00\x00\x00 \x00\x00\x00l\x00\x00\x00o\x00\x00\x00v\x00\x00\x00e\x00\x00\x00 \x00\x00\x00y\x00\x00\x00o\x00\x00\x00u\x00\x00\x00!\x00\x00\x00'

# %% [markdown]
# (b) Consider the following (incorrect) function, which is intended to decode a UTF-8 byte string into
# a Unicode string. Why is this function incorrect? Provide an example of an input byte string
# that yields incorrect results.
#
# ```python
# def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
#     return "".join([bytes([b]).decode("utf-8") for b in bytestring])
# decode_utf8_bytes_to_str_wrong("hello".encode("utf-8"))
# ```

# %%
def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
    return "".join([bytes([b]).decode("utf-8") for b in bytestring])
decode_utf8_bytes_to_str_wrong("我想睡覺了，不要吵我".encode("utf-8"))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[10], line 3
#       1 def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
#       2     return "".join([bytes([b]).decode("utf-8") for b in bytestring])
# ----> 3 decode_utf8_bytes_to_str_wrong("我想睡覺了，不要吵我".encode("utf-8"))
#
# Cell In[10], line 2, in decode_utf8_bytes_to_str_wrong(bytestring)
#       1 def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
# ----> 2     return "".join([bytes([b]).decode("utf-8") for b in bytestring])
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe6 in position 0: unexpected end of data

# %% [markdown]
# (c) Give a two byte sequence that does not decode to any Unicode character(s).

# %%
bytes([255, 5]).decode("utf-8")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 bytes([255, 5]).decode("utf-8")
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte

# %%
import json
with open("outputs/tinystories_bpe/vocab.json", "r") as f:
    lines = f.readline()
    vocab = json.loads(lines)

print(len(vocab))
# Out:
# 10000
